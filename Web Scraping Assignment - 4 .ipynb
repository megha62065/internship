# %% [markdown]
# # Web Scraping Assignment - 4

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# # 1.Scrape the details of most viewed videos on YouTube from Wikipedia.
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
#
# You need to find following details:
#
# A) Rank
#
# B) Name
#
# C) Artist
#
# D) Upload date
#
# E) Views

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
# Getting the webpage of mentioned url 
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)

# %%
#creating empty list
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

# %% [markdown]
#  Scrapping the data

# %%
#Scraping data of rank details
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[1]')[:30]:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')
        

#Scraping data of video names
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[2]')[:30]:
        Name.append(i.text)
except NoSuchElementException:
    Name.append('-')

#Scraping data of artist name
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[3]')[:30]:
        Artist.append(i.text)
except NoSuchElementException:        
    Artist.append('-')
    
#Scraping data of upload dates
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[5]')[:30]:
        Upload_date.append(i.text)
except NoSuchElementException:        
    Upload_date.append('-')
    
    
#Scraping data of views
try:
    for i in driver.find_elements(By.XPATH,'//table[@class="wikitable sortable jquery-tablesorter"]//tbody//tr//td[4]')[:30]:
        Views.append(i.text)
except NoSuchElementException:
    Views.append('-')

# %%
#DATA FRAMEING
Youtube=pd.DataFrame({})
Youtube['Rank'] = Rank
Youtube['Name'] = Name
Youtube['Artist'] = Artist
Youtube['Uploaded Date'] = Upload_date
Youtube['Views'] = Views

# %%
#Printing data frame
Youtube
# Out:
#    Rank                                             Name  \
# 0    1.                            "Baby Shark Dance"[3]
# 1    2.                                   "Despacito"[6]
# 2    3.                       "Johny Johny Yes Papa"[12]
# 3    4.                               "Shape of You"[13]
# 4    5.                              "See You Again"[15]
# 5    6.                                  "Bath Song"[20]
# 6    7.                "Phonics Song with Two Words"[21]
# 7    8.                                "Uptown Funk"[22]
# 8    9.  "Learning Colors – Colorful Eggs on a Farm"[23]
# 9   10.                              "Gangnam Style"[24]
# 10  11.   "Masha and the Bear – Recipe for Disaster"[29]
# 11  12.                          "Wheels on the Bus"[30]
# 12  13.                             "Dame Tu Cosita"[31]
# 13  14.                                      "Sugar"[32]
# 14  15.                                       "Roar"[33]
# 15  16.                             "Counting Stars"[34]
# 16  17.                                      "Sorry"[35]
# 17  18.                                     "Axel F"[36]
# 18  18.                          "Thinking Out Loud"[37]
# 19  20.                        "Baa Baa Black Sheep"[38]
# 20  21.                                 "Dark Horse"[39]
# 21  22.                                      "Faded"[40]
# 22  23.                             "Girls Like You"[41]
# 23  24.                                 "Let Her Go"[42]
# 24  25.                                   "Bailando"[43]
# 25  26.                                    "Lean On"[44]
# 26  27.                                    "Perfect"[45]
# 27  28.           "Waka Waka (This Time for Africa)"[46]
# 28  29.                               "Shake It Off"[47]
# 29  30.          "Humpty the train on a fruits ride"[48]
#
#                                            Artist      Uploaded Date  Views
# 0     Pinkfong Baby Shark - Kids' Songs & Stories      June 17, 2016  11.24
# 1                                      Luis Fonsi   January 12, 2017   7.96
# 2                                     LooLoo Kids    October 8, 2016   6.44
# 3                                      Ed Sheeran   January 30, 2017   5.80
# 4                                     Wiz Khalifa      April 6, 2015   5.62
# 5                      Cocomelon – Nursery Rhymes        May 2, 2018   5.59
# 6                                       ChuChu TV      March 6, 2014   4.85
# 7                                     Mark Ronson  November 19, 2014   4.68
# 8                                     Miroshka TV  February 27, 2018   4.61
# 9                                             Psy      July 15, 2012   4.53
# 10                                     Get Movies   January 31, 2012   4.51
# 11                     Cocomelon – Nursery Rhymes       May 24, 2018   4.31
# 12                                      El Chombo      April 5, 2018   4.05
# 13                                       Maroon 5   January 14, 2015   3.75
# 14                                     Katy Perry  September 5, 2013   3.64
# 15                                    OneRepublic       May 31, 2013   3.63
# 16                                  Justin Bieber   October 22, 2015   3.58
# 17                                     Crazy Frog      June 16, 2009   3.49
# 18                                     Ed Sheeran    October 7, 2014   3.49
# 19                     Cocomelon – Nursery Rhymes      June 25, 2018   3.35
# 20                                     Katy Perry  February 20, 2014   3.34
# 21                                    Alan Walker   December 3, 2015   3.33
# 22                                       Maroon 5       May 31, 2018   3.33
# 23                                      Passenger      July 25, 2012   3.29
# 24                               Enrique Iglesias     April 11, 2014   3.26
# 25                                    Major Lazer     March 22, 2015   3.25
# 26                                     Ed Sheeran   November 9, 2017   3.24
# 27                                        Shakira       June 4, 2010   3.23
# 28                                   Taylor Swift    August 18, 2014   3.20
# 29  Kiddiestv Hindi – Nursery Rhymes & Kids Songs   January 26, 2018   3.14

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="9ff10f7b5424338221a22e87d4f3333e")>>

# %% [markdown]
# # 2.Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
#
# You need to find following details:
#
# A) Match title (I.e. 1 st ODI)
#
# B) Series
#
# C) Place
#
# D) Date
#
# E) Time
#
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')
time.sleep(2)

# Connecting the website
url = " https://www.bcci.tv/"
driver.get(url)
time.sleep(2)

# %%
#going to international fixtures page
International = driver.find_element(By.XPATH,'/html/body/nav/div[1]/div[2]/ul[1]/li[2]/a') 
International.click()

# %%
#Creating Empty List
Name=[]
Series=[]
Place=[]
Date=[]
Time=[]

#Scrapping Name
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="matchOrderText ng-binding ng-scope"]'):
        Name.append(i.text.replace('-',""))
except NoSuchElementException:
    Name.append('-')

#Scrapping Series
try:
    
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding"]'):
        Series.append(i.text)
except NoSuchElementException:
    Series.append('-')
    
#scrapping Place
try:
    for i in driver.find_elements(By.XPATH,'//span[@class="ng-binding ng-scope"]'):
        Place.append(i.text)
except NoSuchElementException:
    Place.append('-')
    
#Scrapping Date
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="ng-binding"]'):
        Date.append(i.text)
except NoSuchElementException:
    Date.append('-')
    
#Scrapping Time
try:
    for i in driver.find_elements(By.XPATH,'//h5[@class="text-right ng-binding"]'):
        Time.append(i.text.replace('IST',""))
except NoSuchElementException:
    Time.append('-')

    
# Creating Dataframe

Int_Fixtures=pd.DataFrame({})

Int_Fixtures['Match Title']=Name
Int_Fixtures['Series']=Series
Int_Fixtures['Place']=Place
Int_Fixtures['Date']=Date
Int_Fixtures['Time']=Time
Int_Fixtures
# Out:
#   Match Title                                       Series  \
# 0   1st T20I   INDIA WOMEN TOUR OF ENGLAND T20 SERIES 2022
# 1   2nd T20I   INDIA WOMEN TOUR OF ENGLAND T20 SERIES 2022
# 2   3rd T20I   INDIA WOMEN TOUR OF ENGLAND T20 SERIES 2022
# 3    1st ODI   INDIA WOMEN TOUR OF ENGLAND ODI SERIES 2022
# 4   1st T20I       AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 5    2nd ODI   INDIA WOMEN TOUR OF ENGLAND ODI SERIES 2022
# 6   2nd T20I       AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 7    3rd ODI   INDIA WOMEN TOUR OF ENGLAND ODI SERIES 2022
#
#                                            Place         Date       Time
# 0                              Riverside Ground,  10 SEP 2022  11:30 PM
# 1                                 County Ground,  13 SEP 2022  10:30 PM
# 2                                 County Ground,  15 SEP 2022  11:00 PM
# 3                                 County Ground,  18 SEP 2022   3:30 PM
# 4  Punjab Cricket Association IS Bindra Stadium,  20 SEP 2022   7:30 PM
# 5                            St Lawrence Ground,  21 SEP 2022   5:30 PM
# 6          Vidarbha Cricket Association Stadium,  23 SEP 2022   7:30 PM
# 7                         Lord's Cricket Ground,  24 SEP 2022   3:30 PM

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="8b6a62aae7f0b103951908e0e9376491")>>

# %% [markdown]
# # 3.Scrape the details of selenium exception from guru99.com.\
# Url = https://www.guru99.com/
#
# You need to find following details:
#
# A) Name
#
# B) Description
#
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
# Creating an instance of webdriver for google chrome
driver=webdriver.Chrome(r"chromedriver.exe")
driver.maximize_window()
# Using webdriver we'll now open the selenium exception handling page chrome
driver.get("https://www.guru99.com/")
driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[2]/div[1]/div/ul[1]/li[3]/a').click()

driver.find_element(By.XPATH,'/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a/strong').click()
time.sleep(5)


Name=[]
Description=[]

guru99=driver.find_elements(By.XPATH,'//p//strong')
for i in guru99:
    Name.append(i.text)


guru99=driver.find_elements(By.XPATH,'//div[@class="entry-content single-content"]//p')
for i in guru99:
    Description.append(i.text)


Desc=[]
for i in range(2,43):
    Desc.append(Description[i].split(':')[1])


Data={'Name':Name[1:42],'Description':Desc}

df=pd.DataFrame(Data)

df
# Out:
#                                         Name  \
# 0             1. ElementNotVisibleException:
# 1          2. ElementNotSelectableException:
# 2                 3. NoSuchElementException:
# 3                   4. NoSuchFrameException:
# 4                5. NoAlertPresentException:
# 5                  6. NoSuchWindowException:
# 6         7. StaleElementReferenceException:
# 7               8. SessionNotFoundException:
# 8                       9. TimeoutException:
# 9                    10. WebDriverException:
# 10            11. ConnectionClosedException:
# 11     12. ElementClickInterceptedException:
# 12      13. ElementNotInteractableException:
# 13             14. ErrorInResponseException:
# 14  15. ErrorHandler.UnknownServerException:
# 15         16. ImeActivationFailedException:
# 16             17. ImeNotAvailableException:
# 17         18. InsecureCertificateException:
# 18             19. InvalidArgumentException:
# 19         20. InvalidCookieDomainException:
# 20          21. InvalidCoordinatesException:
# 21         22. InvalidElementStateException:
# 22            23. InvalidSessionIdException:
# 23       24. InvalidSwitchToTargetException:
# 24                  25. JavascriptException:
# 25                        26. JsonException:
# 26             27. NoSuchAttributeException:
# 27       28. MoveTargetOutOfBoundsException:
# 28               29. NoSuchContextException:
# 29                30. NoSuchCookieException:
# 30                    31. NotFoundException:
# 31          32. RemoteDriverServerException:
# 32                  33. ScreenshotException:
# 33           34. SessionNotCreatedException:
# 34           35. UnableToSetCookieException:
# 35           36. UnexpectedTagNameException:
# 36              37. UnhandledAlertException:
# 37      38. UnexpectedAlertPresentException:
# 38               39. UnknownMethodException:
# 39          40. UnreachableBrowserException:
# 40          41. UnsupportedCommandException:
#
#                                           Description
# 0    This type of Selenium exception occurs when a...
# 1    This Selenium exception occurs when an elemen...
# 2    This Exception occurs if an element could not...
# 3    This Exception occurs if the frame target to ...
# 4    This Exception occurs when you switch to no p...
# 5    This Exception occurs if the window target to...
# 6    This Selenium exception occurs happens when t...
# 7    The WebDriver is acting after you quit the br...
# 8    Thrown when there is not enough time for a co...
# 9    This Exception takes place when the WebDriver...
# 10   This type of Exception takes place when there...
# 11   The command may not be completed as the eleme...
# 12   This Selenium exception is thrown when any el...
# 13   This happens while interacting with the Firef...
# 14   Exception is used as a placeholder in case if...
# 15   This expectation will occur when IME engine a...
# 16    It takes place when IME support is unavailable.
# 17   Navigation made the user agent to hit a certi...
# 18   It occurs when an argument does not belong to...
# 19   This happens when you try to add a cookie und...
# 20   This type of Exception matches an interacting...
# 21   It occurs when command can’t be finished when...
# 22   This Exception took place when the given sess...
# 23   This occurs when the frame or window target t...
# 24   This issue occurs while executing JavaScript ...
# 25   It occurs when you afford to get the session ...
# 26   This kind of Exception occurs when the attrib...
# 27   It takes place if the target provided to the ...
# 28           ContextAware does mobile device testing.
# 29   This Exception occurs when no cookie matching...
# 30   This Exception is a subclass of WebDriverExce...
# 31   This Selenium exception is thrown when the se...
# 32            It is not possible to capture a screen.
# 33   It happens when a new session could not be su...
# 34   This occurs if a driver is unable to set a co...
# 35   Happens if a support class did not get a web ...
# 36   This expectation occurs when there is an aler...
# 37   It occurs when there is the appearance of an ...
# 38   This Exception happens when the requested com...
# 39   This Exception occurs only when the browser i...
# 40   This occurs when remote WebDriver doesn’t sen...

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="de2079c3e58907a9b59c75a6718734f5")>>

# %% [markdown]
# # 4.Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
#
# You have to find following details:
#
# A) Rank
#
# B) State
#
# C) GSDP(18-19)
#
# D) GSDP(17-18)
#
# E) Share(2017)
#
# F) GDP($ billion)
#
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
# Getting the webpage of mentioned url 
url = "http://statisticstimes.com/"
driver.get(url)

# %%
#Clicking on economy section
economy = driver.find_element(By.XPATH,'//div[@class="navbar"]//div[2]//button').click()

urls = driver.find_element(By.XPATH,'//div[@class="dropdown-content"]//a[3]')
ineco_page = urls.get_attribute("href")
#Going to indian economy page
driver.get(ineco_page)  
time.sleep(5)

# %%
#Creating empty list
Rank = []
State = []
GSDP_1 = []
GSDP_2 = []
Share = []
GDP = []

# %%
#get the url of page containing GDP of indian states
sta_GDP = driver.find_element(By.XPATH,'//ul[@style="list-style-type:none;margin-left:20px;"]/li/a')
GDP_url = sta_GDP.get_attribute("href")

driver.get(GDP_url)
time.sleep(6)


#Scraping data of rank
for i in driver.find_elements(By.XPATH,'//div[@id="table_id_wrapper"]//tbody//tr//td[1]'):
    Rank.append(i.text)

    
#Scraping data of state name
for i in driver.find_elements(By.XPATH,'//div[@id="table_id_wrapper"]//tbody//tr//td[2]'):
    State.append(i.text)

    
# Scraping data of GSDP at current price (18-19)
for i in driver.find_elements(By.XPATH,'//div[@id="table_id_wrapper"]//tbody//tr//td[3]'):
    GSDP_1.append(i.text)

    
#Scraping data of GSDP at current price (17-18)
for i in driver.find_elements(By.XPATH,'//div[@id="table_id_wrapper"]//tbody//tr//td[4]'):
    GSDP_2.append(i.text)

    
#Scraping data of Share(2017)
for i in driver.find_elements(By.XPATH,'//div[@id="table_id_wrapper"]//tbody//tr//td[5]'):
    Share.append(i.text)

    
#Scraping data of GDP($ billion)
for i in driver.find_elements(By.XPATH,'//div[@id="table_id_wrapper"]//tbody//tr//td[6]'):
    GDP.append(i.text)

# %%
#DataFraming
data=list(zip(Rank,State,GSDP_1,GSDP_2,Share,GDP))

# %%
df=pd.DataFrame(data,columns=['Rank','Indian_State','GSDP(19-20)','GSDP(18-19)','Share','GDP'])

# %%
df
# Out:
#    Rank               Indian_State GSDP(19-20) GSDP(18-19)   Share      GDP
# 0     1                Maharashtra           -   2,632,792  13.94%  399.921
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%  247.629
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%  240.726
# 3     4                    Gujarat           -   1,502,899   7.96%  228.290
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%  226.806
# 5     6                West Bengal   1,253,832   1,089,898   5.77%  165.556
# 6     7                  Rajasthan   1,020,989     942,586   4.99%  143.179
# 7     8             Andhra Pradesh     972,782     862,957   4.57%  131.083
# 8     9                  Telangana     969,604     861,031   4.56%  130.791
# 9    10             Madhya Pradesh     906,672     809,592   4.29%  122.977
# 10   11                     Kerala           -     781,653   4.14%  118.733
# 11   12                      Delhi     856,112     774,870   4.10%  117.703
# 12   13                    Haryana     831,610     734,163   3.89%  111.519
# 13   14                      Bihar     611,804     530,363   2.81%   80.562
# 14   15                     Punjab     574,760     526,376   2.79%   79.957
# 15   16                     Odisha     521,275     487,805   2.58%   74.098
# 16   17                      Assam           -     315,881   1.67%   47.982
# 17   18               Chhattisgarh     329,180     304,063   1.61%   46.187
# 18   19                  Jharkhand     328,598     297,204   1.57%   45.145
# 19   20                Uttarakhand           -     245,895   1.30%   37.351
# 20   21            Jammu & Kashmir           -     155,956   0.83%   23.690
# 21   22           Himachal Pradesh     165,472     153,845   0.81%   23.369
# 22   23                        Goa      80,449      73,170   0.39%   11.115
# 23   24                    Tripura      55,984      49,845   0.26%    7.571
# 24   25                 Chandigarh           -      42,114   0.22%    6.397
# 25   26                 Puducherry      38,253      34,433   0.18%    5.230
# 26   27                  Meghalaya      36,572      33,481   0.18%    5.086
# 27   28                     Sikkim      32,496      28,723   0.15%    4.363
# 28   29                    Manipur      31,790      27,870   0.15%    4.233
# 29   30                   Nagaland           -      27,283   0.14%    4.144
# 30   31          Arunachal Pradesh           -      24,603   0.13%    3.737
# 31   32                    Mizoram      26,503      22,287   0.12%    3.385
# 32   33  Andaman & Nicobar Islands           -           -       -        -

# %% [markdown]
# # 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
#
# You have to find the following details:
#
# A) Repository title
#
# B) Repository description
#
# C) Contributors count
#
# D) Language used
#
# ASSIGNMENT
#
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
# Connecting to the webdriver
driver=webdriver.Chrome(r"chromedriver.exe")

# %%
#getting the desired webpage.
url='https://github.com/'
driver.get(url)
time.sleep(2)

# %%
#Getting explore button and clicking on it
explore = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details")

#Selecting trending option
trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)

# making empty lists    
repo_urls=[]
Contributors_count=[]
Language_used=[]
repo_title=[]
repo_desc=[]

#scraping repositories urls
repos=driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']/a")
for i in repos:
    repo_urls.append(i.get_attribute('href'))
time.sleep(2)    
    
#scraping repositories title
repo_title=[]
try:
    repos=driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']")
    for i in repos:
        repo_title.append(i.text)
except NoSuchElementException:#handling no such element exception
    repo_title.append('No details available')
time.sleep(3)
    
    
for i in repo_urls:
    driver.get(i)
    l=[]
    time.sleep(3)
     #scraping repositories discription
    try:          
        repo_desc.append(driver.find_element(By.XPATH,"/html/body/div[4]/div/main/turbo-frame/div/div/div/div[3]/div[2]/div/div[1]/div/p").text)
    except:
        repo_desc.append('-')
    
    #scraping contributors count
    try:
        count=driver.find_element(By.XPATH,"//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        Contributors_count.append(count.text)
    except NoSuchElementException:#handling no such element exception
        Contributors_count.append('No details available')
    time.sleep(2)
    
     #scraping languages used   
    languages=driver.find_elements(By.XPATH,"//li[@class='d-inline']//a//span[1]")
    if languages:    
        for i in languages:
            l.append(i.text)
    else:
        l.append('No languages used')
    Language_used.append(l)   
    
time.sleep(2)   
#creating dataframe
df=pd.DataFrame({'Title':repo_title,
                'Description':repo_desc,
                'Contributors_count':Contributors_count,
                'Language_used':Language_used})
df
# Out:
#                                                Title  \
# 0             AUTOMATIC1111 / stable-diffusion-webui
# 1                            MaikKlein / unreal-rust
# 2                                      lapce / lapce
# 3             Sanakan8472 / copy-dialog-lunar-lander
# 4                   DroidKaigi / conference-app-2022
# 5   total-typescript / beginners-typescript-tutorial
# 6                                   apache / airflow
# 7                   alexeygrigorev / mlbookcamp-code
# 8                            vmware-tanzu / kubeapps
# 9                              JoelGMSec / EvilnoVNC
# 10                          devsuperior / sds-dsmeta
# 11       girliemac / a-picture-is-worth-a-1000-words
# 12                        CompVis / stable-diffusion
# 13                              valence-rs / valence
# 14                                   ruanyf / weekly
# 15                               opa334 / TrollStore
# 16                     rolling-scopes-school / tasks
# 17                      gndx / javascript-challenges
# 18                donnemartin / system-design-primer
# 19                       jackfrued / Python-100-Days
# 20                 Nickyie / Cybersecurity-Resources
# 21                   BehaviorTree / BehaviorTree.CPP
# 22                               dbt-labs / dbt-core
# 23                                    coqui-ai / TTS
# 24                            umami-software / umami
#
#                                           Description    Contributors_count  \
# 0                             Stable Diffusion web UI                    13
# 1                Rust integration for Unreal Engine 5  No details available
# 2   Lightning-fast and Powerful Code Editor writte...                    62
# 3   Play lunar lander in you windows file copy dialog                     3
# 4     The Official Conference App for DroidKaigi 2022                    43
# 5    An interactive TypeScript tutorial for beginners                    10
# 6   Apache Airflow - A platform to programmaticall...                 2,182
# 7   The code from the Machine Learning Bookcamp bo...                    35
# 8   A web-based UI for deploying and managing appl...                    85
# 9                       Ready to go Phishing Platform  No details available
# 10                                                  -  No details available
# 11  I am trying to describe complex matters in sim...                     4
# 12                                                  -                     7
# 13   A Rust framework for building Minecraft servers.                     6
# 14                                      科技爱好者周刊，每周五发布                    31
# 15  Jailed iOS app that can install IPAs permanent...                     8
# 16                                                  -                   184
# 17                                                  -  No details available
# 18  Learn how to design large-scale systems. Prep ...                   115
# 19                                Python - 100天从新手到大师                    12
# 20       A Library of various cybersecurity resources                     2
# 21  Behavior Trees Library in C++. Batteries inclu...                    78
# 22  dbt enables data analysts and engineers to tra...                   220
# 23  🐸💬 - a deep learning toolkit for Text-to-Speec...                    88
# 24  Umami is a simple, fast, privacy-focused alter...                   164
#
#                                         Language_used
# 0                [Python, JavaScript, Batchfile, CSS]
# 1                                         [Rust, C++]
# 2                                              [Rust]
# 3                                                [C#]
# 4                                     [Kotlin, Swift]
# 5                            [TypeScript, JavaScript]
# 6   [Python, TypeScript, Shell, HTML, JavaScript, ...
# 7                                  [Jupyter Notebook]
# 8     [Go, TypeScript, JavaScript, Shell, SCSS, Rust]
# 9       [JavaScript, HTML, Dockerfile, Python, Shell]
# 10                                [No languages used]
# 11                                [No languages used]
# 12                  [Jupyter Notebook, Python, Shell]
# 13                                       [Rust, Java]
# 14                                [No languages used]
# 15                                   [C, Objective-C]
# 16                                       [JavaScript]
# 17                                       [JavaScript]
# 18                                    [Python, Shell]
# 19                   [Python, HTML, Jupyter Notebook]
# 20                                [No languages used]
# 21                                       [C++, CMake]
# 22                                     [Python, HTML]
# 23  [Python, Jupyter Notebook, HTML, Shell, Makefi...
# 24                                  [JavaScript, CSS]

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="dd912877a2c1d1dfa10d854340df3640")>>

# %% [markdown]
# # 6. Scrape the details of top 100 songs on billiboard.com.
# Url = https:/www.billboard.com/
#
# You have to find the following details:
#
# A) Song name
#
# B) Artist name
#
# C) Last week rank
#
# D) Peak rank
#
# E) Weeks on board
#
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
# to get web drivers
driver=webdriver.Chrome(r"chromedriver.exe")  
time.sleep(2)

# Opening the billboard
url = "https://www.billboard.com/"
driver.get(url)
time.sleep(2)

# %%
#Clicking on charts
driver.find_element(By.XPATH,"/html/body/div[3]/header/div[1]/div/div/div[2]/div/nav/ul/li[1]").click()

# %%
# clicking view chart
driver.find_element(By.XPATH,"/html/body/div[3]/main/div[2]/div[1]/div[2]/div/div[2]/div[3]/a").click()

# %%
#Creating empty list
Name = []
Artist = []
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# %%
#scraping song names
try:
    names=driver.find_elements(By.XPATH,'//div[@class="o-chart-results-list-row-container"]//h3')
    for i in names:
        Name.append(i.text)
except NoSuchElementException:       
    Name.append('No details available')
time.sleep(2)    
Name[::4][:100]
# Out:
# ['Pink Venom',
#  'Titi Me Pregunto',
#  'Super Freaky Girl',
#  'Bad Habit',
#  'Moscow Mule',
#  'Provenza',
#  'Calm Down',
#  'Save Your Tears',
#  'Left And Right',
#  'I Like You (A Happier Song)',
#  'Blinding Lights',
#  'Doja',
#  'Party',
#  'Beautiful',
#  'Enemy',
#  'Last Last',
#  'Pepas',
#  'Until I Found You',
#  'Perfect',
#  'Use This Gospel (Remix)',
#  'Starboy',
#  'Golden Hour',
#  'Lokera',
#  'Where Are You Now',
#  "I'm Invincible",
#  'Unstoppable',
#  'Summertime Sadness',
#  '505',
#  'Keep Going',
#  'Un Coco',
#  'Woman',
#  'Without Me',
#  'Good 4 U',
#  'Murder In My Mind',
#  'Victoria’s Secret',
#  "Don't You Worry",
#  'Bohemian Rhapsody',
#  'I Was Never There',
#  'For My Hand',
#  'Wasted On You',
#  'Every Breath You Take',
#  "Don't Stop Believin'",
#  "Don't Start Now",
#  "Let's Pray",
#  'Dreams',
#  'Normal',
#  "It Ain't Safe",
#  'Thunderstruck',
#  '5 Foot 9',
#  'Blank Space',
#  'Pink Venom',
#  'Titi Me Pregunto',
#  'Super Freaky Girl',
#  'Bad Habit',
#  'Moscow Mule',
#  'Provenza',
#  'Calm Down',
#  'Save Your Tears',
#  'Left And Right',
#  'I Like You (A Happier Song)',
#  'Blinding Lights',
#  'Doja',
#  'Party',
#  'Beautiful',
#  'Enemy',
#  'Last Last',
#  'Pepas',
#  'Until I Found You',
#  'Perfect',
#  'Use This Gospel (Remix)',
#  'Starboy',
#  'Golden Hour',
#  'Lokera',
#  'Where Are You Now',
#  "I'm Invincible",
#  'Unstoppable',
#  'Summertime Sadness',
#  '505',
#  'Keep Going',
#  'Un Coco',
#  'Woman',
#  'Without Me',
#  'Good 4 U',
#  'Murder In My Mind',
#  'Victoria’s Secret',
#  "Don't You Worry",
#  'Bohemian Rhapsody',
#  'I Was Never There',
#  'For My Hand',
#  'Wasted On You',
#  'Every Breath You Take',
#  "Don't Stop Believin'",
#  "Don't Start Now",
#  "Let's Pray",
#  'Dreams',
#  'Normal',
#  "It Ain't Safe",
#  'Thunderstruck',
#  '5 Foot 9',
#  'Blank Space']

# %%
#scraping artist names
try:
    artist=driver.find_elements(By.XPATH,'//li[@class="lrv-u-width-100p"]//span')
    for i in artist:
        Artist.append(i.text)
except NoSuchElementException:     
    Artist.append('-')
time.sleep(2)    
Artist[::7][:100]
# Out:
# ['BLACKPINK',
#  'Harry Styles',
#  'Bad Bunny & Chencho Corleone',
#  'Bizarrap & Quevedo',
#  'Bad Bunny',
#  'Elton John & Britney Spears',
#  'Rosalia',
#  'OneRepublic',
#  'Nicki Minaj',
#  'Bad Bunny',
#  'Manuel Turizo',
#  'Kate Bush',
#  'Steve Lacy',
#  'Chris Brown',
#  'Bad Bunny & Bomba Estereo',
#  'Glass Animals',
#  'Bad Bunny',
#  'TWICE',
#  'David Guetta & Bebe Rexha',
#  'IVE',
#  'Karol G',
#  'Joji',
#  'Karol G x Maldy',
#  'DJ Khaled Featuring Rick Ross, Lil Wayne, JAY-Z, John Legend & Fridayy',
#  'Rema',
#  'Rosa Linn',
#  'Elton John & Dua Lipa',
#  'Lizzo',
#  'The Weeknd & Ariana Grande',
#  'Beyonce',
#  'Nicky Youre & dazy',
#  'Tom Odell',
#  'Charlie Puth Featuring Jung Kook',
#  'DJ Khaled Featuring Drake & Lil Baby',
#  'The Kid LAROI & Justin Bieber',
#  'Bad Bunny',
#  'Post Malone Featuring Doja Cat',
#  'Ado',
#  'Drake Featuring 21 Savage',
#  'Harry Styles',
#  'The Weeknd',
#  'Ed Sheeran',
#  'Dua Lipa',
#  'Bad Bunny & Jhay Cortez',
#  'Central Cee',
#  'Future Featuring Drake & Tems',
#  'James Hype & Miggy Dela Rosa',
#  'Ed Sheeran',
#  'Bad Bunny & Rauw Alejandro',
#  'Imagine Dragons',
#  'Shakira & Rauw Alejandro',
#  'Doja Cat',
#  'DJ Khaled Featuring Future & SZA',
#  'The Weeknd',
#  'NewJeans',
#  'Camila Cabello Featuring Ed Sheeran',
#  'Imagine Dragons X JID',
#  'NewJeans',
#  'Morgan Wallen',
#  'Jack Harlow',
#  'Burna Boy',
#  'DJ Khaled Featuring Future & Lil Baby',
#  'Ghost',
#  'Lil Tjay',
#  'Farruko',
#  'The Neighbourhood',
#  'Bad Bunny & Tony Dize',
#  'benny blanco, BTS & Snoop Dogg',
#  'Stephen Sanchez',
#  'Luke Combs',
#  'Polima WestCoast Featuring Pailita',
#  'Marshmello & Khalid',
#  'Ed Sheeran',
#  'Luar La L',
#  'Lasso',
#  'Bad Bunny',
#  'DJ Khaled Featuring Kanye West & Eminem',
#  'Coldplay',
#  'Billie Eilish',
#  'Justin Bieber',
#  'The Weeknd Featuring Daft Punk',
#  'Lil Nas X & Jack Harlow',
#  'Harry Styles',
#  'Calvin Harris & Dua Lipa',
#  'JVKE',
#  'Imagine Dragons',
#  'Yung Gravy',
#  'Becky G X Karol G',
#  'Rauw Alejandro, Lyanno & Brray',
#  'Paloma Faith',
#  'Rels B',
#  'Pinkfong',
#  'Lost Frequencies & Calum Scott',
#  'Adele',
#  'GAYLE',
#  'Ruth B.',
#  'Ado',
#  'Bad Bunny',
#  'DJ Khaled Featuring Juice WRLD',
#  'Beyonce']

# %%
#scraping last week rank of the song
try:
    last_rank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]')
    for i in last_rank:
        Last_week_rank.append(i.text)
except NoSuchElementException:      
    Last_week_rank.append('-')
    time.sleep(2)    
Last_week_rank[::2][:100]
# Out:
# ['1',
#  '3',
#  '4',
#  '2',
#  '5',
#  '-',
#  '6',
#  '8',
#  '7',
#  '10',
#  '12',
#  '9',
#  '11',
#  '19',
#  '14',
#  '13',
#  '15',
#  '-',
#  '-',
#  '48',
#  '16',
#  '17',
#  '-',
#  '-',
#  '89',
#  '20',
#  '22',
#  '21',
#  '24',
#  '18',
#  '26',
#  '36',
#  '25',
#  '47',
#  '27',
#  '44',
#  '29',
#  '23',
#  '28',
#  '30',
#  '32',
#  '33',
#  '38',
#  '35',
#  '31',
#  '34',
#  '43',
#  '40',
#  '42',
#  '50',
#  '41',
#  '45',
#  '-',
#  '57',
#  '52',
#  '46',
#  '49',
#  '54',
#  '61',
#  '51',
#  '53',
#  '-',
#  '102',
#  '-',
#  '55',
#  '58',
#  '59',
#  '37',
#  '56',
#  '62',
#  '60',
#  '77',
#  '73',
#  '71',
#  '93',
#  '63',
#  '-',
#  '79',
#  '64',
#  '69',
#  '85',
#  '72',
#  '75',
#  '67',
#  '-',
#  '81',
#  '90',
#  '66',
#  '112',
#  '82',
#  '70',
#  '88',
#  '80',
#  '87',
#  '84',
#  '86',
#  '74',
#  '83',
#  '-',
#  '65']

# %%
#scraping song's peak rank
try:
    peak=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-hidden@mobile-max"]')
    for i in peak:
        Peak_rank.append(i.text)
except NoSuchElementException:       
    Peak_rank.append('-')
time.sleep(2)    
Peak_rank[1::2][:100]
# Out:
# ['1',
#  '',
#  '',
#  '1',
#  '1',
#  '2',
#  '1',
#  '4',
#  '6',
#  '6',
#  '8',
#  '5',
#  '7',
#  '11',
#  '1',
#  '10',
#  '14',
#  '4',
#  '1',
#  '2',
#  '18',
#  '19',
#  '20',
#  '6',
#  '2',
#  '23',
#  '24',
#  '25',
#  '20',
#  '3',
#  '6',
#  '1',
#  '6',
#  '26',
#  '32',
#  '5',
#  '10',
#  '1',
#  '16',
#  '7',
#  '20',
#  '3',
#  '2',
#  '2',
#  '3',
#  '2',
#  '9',
#  '19',
#  '2',
#  '43',
#  '1',
#  '8',
#  '45',
#  '11',
#  '28',
#  '53',
#  '54',
#  '52',
#  '5',
#  '3',
#  '54',
#  '22',
#  '2',
#  '39',
#  '62',
#  '63',
#  '64',
#  '7',
#  '51',
#  '17',
#  '6',
#  '44',
#  '38',
#  '24',
#  '66',
#  '30',
#  '71',
#  '75',
#  '7',
#  '77',
#  '75',
#  '6',
#  '16',
#  '52',
#  '2',
#  '9',
#  '43',
#  '85',
#  '52',
#  '82',
#  '4',
#  '89',
#  '75',
#  '51',
#  '38',
#  '22',
#  '1',
#  '1',
#  '51',
#  '74']

# %%
#scraping number of weeks on board
try:
    weeks=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max u-hidden@mobile-max"]')
    for i in weeks:
        Weeks_on_board.append(i.text)
except NoSuchElementException:       #handling no such element exception
    Weeks_on_board.append('-')
time.sleep(2)    
Weeks_on_board[1::2][:100]
# Out:
# ['2',
#  '22',
#  '17',
#  '8',
#  '17',
#  '1',
#  '5',
#  '13',
#  '3',
#  '17',
#  '8',
#  '14',
#  '8',
#  '6',
#  '17',
#  '87',
#  '17',
#  '1',
#  '1',
#  '2',
#  '19',
#  '12',
#  '1',
#  '1',
#  '9',
#  '8',
#  '55',
#  '20',
#  '87',
#  '11',
#  '15',
#  '70',
#  '10',
#  '4',
#  '60',
#  '17',
#  '13',
#  '5',
#  '11',
#  '15',
#  '104',
#  '51',
#  '100',
#  '17',
#  '6',
#  '18',
#  '11',
#  '62',
#  '17',
#  '25',
#  '19',
#  '14',
#  '1',
#  '26',
#  '4',
#  '26',
#  '44',
#  '4',
#  '16',
#  '21',
#  '13',
#  '1',
#  '2',
#  '1',
#  '59',
#  '101',
#  '17',
#  '4',
#  '16',
#  '11',
#  '18',
#  '12',
#  '104',
#  '3',
#  '9',
#  '17',
#  '1',
#  '73',
#  '57',
#  '50',
#  '61',
#  '58',
#  '104',
#  '14',
#  '1',
#  '104',
#  '8',
#  '29',
#  '3',
#  '16',
#  '4',
#  '103',
#  '51',
#  '47',
#  '42',
#  '33',
#  '3',
#  '17',
#  '1',
#  '5']

# %%
df=pd.DataFrame({'Song_Name':Name[::4][:100],
                'Artist_Name':Artist[::7][:100],
                'Last_week_rank':Last_week_rank[::2][:100],
                'Peak':Peak_rank[1::2][:100],
                'Weeks_on_chart':Weeks_on_board[1::2][:100]})
df
# Out:
#             Song_Name                     Artist_Name Last_week_rank Peak  \
# 0          Pink Venom                       BLACKPINK              1    1
# 1    Titi Me Pregunto                    Harry Styles              3
# 2   Super Freaky Girl    Bad Bunny & Chencho Corleone              4
# 3           Bad Habit              Bizarrap & Quevedo              2    1
# 4         Moscow Mule                       Bad Bunny              5    1
# ..                ...                             ...            ...  ...
# 95             Normal                         Ruth B.             86   22
# 96      It Ain't Safe                             Ado             74    1
# 97      Thunderstruck                       Bad Bunny             83    1
# 98           5 Foot 9  DJ Khaled Featuring Juice WRLD              -   51
# 99        Blank Space                         Beyonce             65   74
#
#    Weeks_on_chart
# 0               2
# 1              22
# 2              17
# 3               8
# 4              17
# ..            ...
# 95             33
# 96              3
# 97             17
# 98              1
# 99              5
#
# [100 rows x 5 columns]

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="190b677dd13d1ba9495a29fb6774b93a")>>

# %% [markdown]
# # 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
#
# You have to find the following details:
#
# A) Name
#
# B) Designation
#
# C) Company
#
# D) Skills they hire for
#
# E) Location
#
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
# connect to webdriver
driver=webdriver.Chrome('chromedriver.exe')
driver.maximize_window()
time.sleep(2)

# Connecting the website
url = " https://www.naukri.com/hr-recruiters-consultants"
driver.get(url)
time.sleep(2)

# %%
#clicking on recruiters link
recruiters=driver.find_element(By.XPATH,"//a[@title='Search Recruiters']")
driver.get(recruiters.get_attribute('href'))
time.sleep(1)

# %%
#accesing search bar
search=driver.find_element(By.XPATH,"//input[@class='sugInp']")
search.send_keys("Data Science")
time.sleep(1)

# %%
#clicking on search button
button=driver.find_element(By.XPATH,"//button[@id='qsbFormBtn']")
button.click()
time.sleep(1)

# %%
#Creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

# %%
#Scraping data of Names
for i in driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


#Scraping data of Designation

for i in driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']"):
    Designation.append(i.text)
    

#Scraping data of company name

for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)

    
#Scraping data of locations

for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]//span"):
    Location.append(i.text)
time.sleep(3)

# %%
print(len(Name),len(Designation),len(Company),len(Location))
# Out:
# 50 50 50 148

# %%
# Creating dataframe 
Naukri=pd.DataFrame({})

Naukri['Name'] = Name
Naukri['Designation'] = Designation
Naukri['Company'] = Company
Naukri['Location'] = Location[:50]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Vaishnavi Kudalkar
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                Dhruv Dev Dubey
# 18                                Sakshi Chhikara
# 19                                    Ruchi Dhote
# 20                                  Manisha Yadav
# 21                                    Riya Rajesh
# 22                           Rashmi Bhattacharjee
# 23                                  Faizan Kareem
# 24                                 Rithika dadwal
# 25                             Sandhya Khandagale
# 26                                      Shaun Rao
# 27                                  Azahar Shaikh
# 28                                          Manas
# 29                                          kumar
# 30                                   Sunil Vedula
# 31                                    Rajat Kumar
# 32                                      Jayanth N
# 33                                         Avodha
# 34                                     Daniel Vaz
# 35                                    Priya Khare
# 36                                    Amit Sharma
# 37                                          Kanan
# 38                           Shashikant Chaudhary
# 39                                           Brad
# 40                                   Rutuja Pawar
# 41                            Madhusudhan Sridhar
# 42                                    Ankit Sinha
# 43                                 Gaurav Chouhan
# 44                                   Rashi Kacker
# 45                                        Ashwini
# 46                                   Balaji Kolli
# 47                                 Rajani Nagaraj
# 48                                    ROHIT Kumar
# 49                                 Amir Chowdhury
#
#                             Designation  \
# 0                            HR Manager
# 1                     Company Recruiter
# 2                            Company HR
# 3                     Company Recruiter
# 4                           Founder CEO
# 5           Recruitment Lead Consultant
# 6                     Programme Manager
# 7                      HR Administrator
# 8                              Director
# 9                        Human Resource
# 10                           HR Manager
# 11                     Executive Hiring
# 12                           Company HR
# 13                           Company HR
# 14                         HR Executive
# 15                         HR Team Lead
# 16                           HR Manager
# 17             Company Recruitment Head
# 18                 Assistant Manager HR
# 19  Senior Executive Talent Acquisition
# 20                         HR Executive
# 21           Manager Talent Acquisition
# 22                              HR Head
# 23                           HR MANAGER
# 24                         HR Recruiter
# 25                         HR Recruiter
# 26              Manager Human Resources
# 27                    Company Recruiter
# 28              Lead Talent acquisition
# 29                           Proprietor
# 30                                  CEO
# 31                          Founder CEO
# 32                      Project Manager
# 33       Business Development Associate
# 34                              Partner
# 35                       Senior Manager
# 36                           Consultant
# 37         senior technology instructor
# 38             HR Recruiter/HR Excutive
# 39        Manager, Technical Recruiting
# 40                  Technical Recruiter
# 41                      Erp Implementer
# 42                       Head Analytics
# 43              Chief Technical Officer
# 44                   Sr Product Manager
# 45             Director Global Delivery
# 46                           Co Founder
# 47                           HR Manager
# 48                            Architect
# 49                     Managing Partner
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                   Infinitive Software Solutions
# 11                              Innominds Software
# 12                                        MoneyTap
# 13              QuantMagnum Technologies Pvt. Ltd.
# 14                             Codeachive learning
# 15                               SocialPrachar.com
# 16                                  BISP Solutions
# 17                                    Confidential
# 18                   BIZ INFOTECNO PRIVATE LIMITED
# 19                           Bristlecone India Ltd
# 20                                        Easi Tax
# 21                     Novelworx Digital Solutions
# 22         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 23                   FirstTech Consaltants Pvt.Ltd
# 24                                Affine Analytics
# 25                 Compumatrice Multimedia Pvt Ltd
# 26                              Exela Technologies
# 27                 NEAL ANALYTICS SERVICES PVT LTD
# 28      Autumn Leaf Consulting Services Private...
# 29                                         trainin
# 30                            Nanoprecise Sci Corp
# 31                  R.S Consultancy &amp; Services
# 32        Dollarbird Information Services Pvt, Ltd
# 33                              Nikitha Palaparthi
# 34                                    Aquis Search
# 35                          Independent Consultant
# 36                                 ASCO consulting
# 37                                         NY INST
# 38  3D India Staffing Research &amp; Consulting...
# 39                                     O.C. Tanner
# 40                                   Demand Matrix
# 41                             MADHUSUDHAN SRIDHAR
# 42                                  Suntech Global
# 43                        Strategic Consulting Lab
# 44                            Impel Labs Pvt. Ltd.
# 45                                    MRP Advisers
# 46                   Saras Solutions India Pvt Ltd
# 47                                     WildJasmine
# 48                             LNT Private Limited
# 49                                     Granular.ai
#
#                                          Location
# 0                                    Aakash Harit
# 1                                      HR Manager
# 2                                           Delhi
# 3                            shravan Kumar Gaddam
# 4                               Company Recruiter
# 5                        Hyderabad / Secunderabad
# 6                        MARSIAN Technologies LLP
# 7                                      Company HR
# 8                                            Pune
# 9                                    Anik Agrawal
# 10                              Company Recruiter
# 11                                      Ahmedabad
# 12                                   subhas patel
# 13                                    Founder CEO
# 14                                  UK - (london)
# 15   Abhishek - Only Analytics Hiring - India and
# 16                    Recruitment Lead Consultant
# 17                              Vadodara / Baroda
# 18  Institute for Financial Management and Resear
# 19                              Programme Manager
# 20                                        Chennai
# 21                                    Balu Ramesh
# 22                               HR Administrator
# 23                                     Trivandrum
# 24                                  Asif Lucknowi
# 25                                       Director
# 26                                         Indore
# 27                                InstaFinancials
# 28                                 Human Resource
# 29                          Bengaluru / Bangalore
# 30                                 Priyanka Akiri
# 31                                     HR Manager
# 32                                      Hyderabad
# 33                                Kalpana Dumpala
# 34                               Executive Hiring
# 35                       Hyderabad / Secunderabad
# 36                                        Mubarak
# 37                                     Company HR
# 38                          Bengaluru / Bangalore
# 39                                 Kushal Rastogi
# 40                                     Company HR
# 41                                         Mumbai
# 42                             Vaishnavi Kudalkar
# 43                                   HR Executive
# 44                                         Mumbai
# 45                             Mahesh Babu Channa
# 46                                   HR Team Lead
# 47                       Hyderabad / Secunderabad
# 48                                   Kapil Devang
# 49                                     HR Manager

# %%
driver.close()

# %% [markdown]
# # 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
#
# You have to find the following details:
#
# A) Book name
#
# B) Author name
#
# C) Volumes sold
#
# D) Publisher
#
# E) Genre

# %%
# to get web drivers
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(2)

# Opening the theguardian.com
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)
time.sleep(2)

# %%
#Creating empty list
Book_name = []
Author = []
Volumes_sold = []
Publisher = []
Genre = []

# %%
#scraping data of book names
for i in driver.find_elements(By.XPATH,"//tbody//tr/td[2]"):
    Book_name.append(i.text)

    
#Scraping data of author names
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author.append(i.text)
    except NoSuchElementException:
        Author.append('-')
time.sleep(1)


#Scraping data of volumes sold
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[4]"):
    Volumes_sold.append(i.text)

    
#Scraping data of publisher names
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[5]"):
    Publisher.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements(By.XPATH,"//tbody/tr/td[6]"):
    Genre.append(i.text)

# %%
#DATA FRAMEING
Novel=pd.DataFrame({})
Novel['Book Name'] = Book_name
Novel['Author'] = Author
Novel['Volume sold'] = Volumes_sold
Novel['Publisher'] = Publisher
Novel['Genre'] = Genre
Novel
# Out:
#                                             Book Name            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="543202671dbe91c9b5775403aa21e9df")>>

# %% [markdown]
# # 9. Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
#
# You have to find the following details:
#
# A) Name
#
# B) Year span
#
# C) Genre
#
# D) Run time
#
# E) Ratings
#
# F) Votes

# %%
# to get web drivers
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(2)

# Opening the imdb.com
url = "https://www.imdb.com/list/ls095964455"
driver.get(url)
time.sleep(2)

# %%
#Creating empty lists.
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# %%
#Scraping data of Names
for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)

    
#Scraping data of Year span
for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)

    
#Scraping data of genre
for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)

    
#Scraping data of Run time
for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    Run_time.append(i.text)

    
#Scraping data of Ratings
for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)

    
#Scraping data of votes
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text)

# %%
#DATA FRAMEING
IMDB=pd.DataFrame({})
IMDB['Name'] = Name
IMDB['Year Span'] = Year_span
IMDB['Genre'] = Genre
IMDB['Run Time'] = Run_time
IMDB['Ratings'] = Ratings
IMDB['Votes'] = Votes
IMDB
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,045,046
# 1    51 min     8.7  1,141,822
# 2    44 min     8.1    967,031
# 3    60 min     7.5    288,559
# 4    43 min     7.6    248,133
# ..      ...     ...        ...
# 95   42 min     7.4     49,503
# 96   50 min     7.8     60,499
# 97   42 min     8.1    194,614
# 98   45 min     7.1     40,994
# 99  572 min     8.6    235,976
#
# [100 rows x 6 columns]

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="d6314c8896117ead9d47488458d943b4")>>

# %% [markdown]
# # 10. Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
#
# You have to find the following details:
#
# A) Dataset name
#
# B) Data type
#
# C) Task
#
# D) Attribute type
#
# E) No of instances
#
# F) No of attribute
#
# G) Year
#
# Note: - from the home page you have to go to the ShowAllDataset page through code

# %%
# to get web drivers
driver=webdriver.Chrome(r"chromedriver.exe")
time.sleep(2)

# Opening the uci.com
url = "https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(2)

# %%
#Finding view all dataset button
view_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")    
page_url = view_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(5)

#Getting page urls containing list of all datasets
all_lst = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")  
lst_url = all_lst.get_attribute("href")           
driver.get(lst_url)
time.sleep(5)

#fetching url for each dataset
data_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")    

urls = []     
for i in data_url:
    urls.append(i.get_attribute("href"))

# %%
#table view
table = driver.find_element(By.XPATH,'/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a')
table.click()

# %%
#Creating empty list
Data_name = []
Data_type = []
Task = []
Attr_type = []
Instances = []
n_attributes = []
Year = []

# %%
#Scraping requiredinfo from urls
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    
    #Scraping Dataset name
    try: 
        ds_name = driver.find_element(By.XPATH,"//span[@class='heading']")
        Data_name.append(ds_name.text)
    except NoSuchElementException:
        Data_name.append('-')
    time.sleep(1)
    
    
    #Scraping data type
    try:
        dtype = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[2]")
        if dtype.text == "N/A": raise NoSuchElementException
        Data_type.append(dtype.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(1)
    
    
    #Scraping Attribute type
    try:
        atype = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]")
        if atype.text == "N/A": raise NoSuchElementException
        Attr_type.append(atype.text)
    except NoSuchElementException:
        Attr_type.append('-')
    time.sleep(1)
    
    
    #scraping Task
    try:
        task = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(1)
    
    
    #Scraping No of instances
    try:
        inst = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[4]")
        if inst.text == "N/A": raise NoSuchElementException
        Instances.append(inst.text)
    except NoSuchElementException:
        Instances.append('-')
    time.sleep(1)
    
    
    #Scraping  No of attribute
    try:
        attr = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]")
        if attr.text == "N/A": raise NoSuchElementException
        n_attributes.append(attr.text)
    except NoSuchElementException:
        n_attributes.append('-')
    time.sleep(1)
    
    
    #scraping year
    try:
        year = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(1)

# %%
#DATA FRAMEING
UCI=pd.DataFrame({})
UCI['Data Name'] = Data_name
UCI['Data Type'] = Data_type
UCI['Task'] = Task
UCI['Attribute type'] = Attr_type
UCI['No of instance'] = Instances
UCI['No of attributes'] = n_attributes
UCI['Year'] = Year
UCI
# Out:
#                                              Data Name  \
# 0         2.4 GHZ Indoor Channel Measurements Data Set
# 1    3D Road Network (North Jutland, Denmark) Data Set
# 2                                  3W dataset Data Set
# 3                          9mers from cullpdb Data Set
# 4    : Simulated Data set of Iraqi tourism places D...
# ..                                                 ...
# 617  Youtube cookery channels viewers comments in H...
# 618     YouTube Multiview Video Games Dataset Data Set
# 619                   YouTube Spam Collection Data Set
# 620                           Z-Alizadeh Sani Data Set
# 621                                       Zoo Data Set
#
#                      Data Type                        Task  \
# 0                 Multivariate              Classification
# 1             Sequential, Text      Regression, Clustering
# 2    Multivariate, Time-Series  Classification, Clustering
# 3                   Sequential  Classification, Regression
# 4                 Multivariate  Classification, Clustering
# ..                         ...                         ...
# 617         Multivariate, Text              Classification
# 618         Multivariate, Text  Classification, Clustering
# 619                       Text              Classification
# 620                          -              Classification
# 621               Multivariate              Classification
#
#            Attribute type No of instance No of attributes  Year
# 0                    Real           7840                5  2018
# 1                    Real         434874                4  2013
# 2           Integer, Real           1984                8  2019
# 3                    Real         158716                4  2021
# 4                       -            232               16  2020
# ..                    ...            ...              ...   ...
# 617                     -           9800                3  2019
# 618         Integer, Real         120000          1000000  2013
# 619                     -           1956                5  2017
# 620         Integer, Real            303               56  2017
# 621  Categorical, Integer            101               17  1990
#
# [622 rows x 7 columns]

# %%
driver.close
# Out:
# <bound method WebDriver.close of <selenium.webdriver.chrome.webdriver.WebDriver (session="2ab49b6f8e9748e2465741c93ee9e3da")>>
